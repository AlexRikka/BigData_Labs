# %%
import logging
logging.basicConfig()
from kazoo.client import KazooClient
from kazoo.protocol.paths import join

# %%
coordinator = KazooClient()
coordinator.start()

# %%
coordinator.get_children('/')
# Out:
# ['mynode', 'zoo', 'zookeeper', 'table']

# %%
coordinator.get_children('/mynode')
# Out:
# ['child0000000000', 'child0000000001']

# %%
coordinator.delete('/mynode/child0000000000')
coordinator.delete('/mynode/child0000000001')
# Out:
# True

# %%
coordinator.get_children('/mynode')
# Out:
# []

# %%
coordinator.create('/mynode/pc2')
# Out:
# '/mynode/pc2'

# %% [markdown]
# Result of running script:
#
# ![image.png](attachment:image.png)
